# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
df = pd.read_csv('../results/connected_components.csv')

# %%
plt.clf()
axis1 = plt.subplot(2,1,1)
axis2 = plt.subplot(2,1,2)
df.plot(x='connected_component_count', y='time', kind='box', ax=axis1)
df.plot(x='connected_component_count', y='time', kind='density', ax=axis2)
plt.show()
